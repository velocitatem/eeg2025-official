# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/eeg2025/startkit/blob/main/challenge_1.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Challenge 1: Cross-Task Transfer Learning!
#
# ## How can we use the knowledge from one EEG Decoding task into another?
#
# Transfer learning is a widespread technique used in deep learning. It uses knowledge learned from one source task/domain in another target task/domain. It has been studied in depth in computer vision, natural language processing, and speech, but what about EEG brain decoding?
#
# The cross-task transfer learning scenario in EEG decoding is remarkably underexplored in comparison to the developers of new models, [Aristimunha et al., (2023)](https://arxiv.org/abs/2308.02408), even though it can be much more useful for real applications, see [Wimpff et al. (2025)](https://arxiv.org/abs/2502.06828), [Wu et al. (2025)](https://arxiv.org/abs/2507.09882).
#
# Our Challenge 1 addresses a key goal in neurotechnology: decoding cognitive function from EEG using the pre-trained knowledge from another. In other words, developing models that can effectively transfer/adapt/adjust/fine-tune knowledge from passive EEG tasks to active tasks.
#
# The ability to generalize and transfer is something critical that we believe should be focused. To go beyond just comparing metrics numbers that are often not comparable, given the specificities of EEG, such as pre-processing, inter-subject variability, and many other unique components of this type of data.
#
# This means your submitted model might be trained on a subset of tasks and fine-tuned on data from another condition, evaluating its capacity to generalize with task-specific fine-tuning.

# %% [markdown]
# __________
#
# Note: For simplicity purposes, we will only show how to do the decoding directly in our target task, and it is up to the teams to think about how to use the passive task to perform the pre-training.

# %% [markdown]
# ---
# ## Summary table for this start kit
#
# In this tutorial, we are going to show in more detail what we want from Challenge 1:
#
# **Contents**:
#
# 0. Understand the Contrast Change Detection - CCD task.
# 1. Understand the [`EEGChallengeDataset`](https://eeglab.org/EEGDash/api/eegdash.html#eegdash.EEGChallengeDataset) object.
# 2. Preparing the dataloaders.
# 3. Building the deep learning model with [`braindecode`](https://braindecode.org/stable/models/models_table.html).
# 4. Designing the training loop.
# 5. Training the model.
# 6. Evaluating test performance.
# 7. Going further, *benchmark go brrr!*
#
#
#
# More contents will be released during the competition inside the [`eegdash`](https://eeglab.org/EEGDash/overview.html) [examples webpage](https://eeglab.org/EEGDash/generated/auto_examples/index.html).
#
# We will establish direct communication channels with you over the next two months, resolve platform issues, and discuss other details.
#
# We are going to do weekly one-hour support time to help teams that may have difficulties with any technical aspects that may arise.
#
# We will have closer communication starting next week, 08/09/2025.
#
# Before we begin, I just want to make a deal with you, ok?
#
# This is a community competition with a strong open-source foundation. When I say open-source, I mean volunteer work.
#
# So, if you see something that does not work or could be improved, first, **please be kind**, and we will fix it together on github, okay?
#
# The entire decoding community will only go further when we stopped solving the same problems over and over again, and it starts working together.
#
# ----

# %% [markdown]
# | The tutorial assumes some prior knowledge of deep learning concepts and EEG concepts:|
# | --- |
# |* Standard neural network architectures, e.g., convolutional neural networks|
# |* Optimization by batch gradient descent and backpropagation|
# |* Overfitting, early stopping, regularisation |
# |* Some knowledge of pytorch and, optionally, of the pytorch Lightning framework|
# |* That you know what EEG is |
# |* that you have basic familiarity with EEG preprocessing |
# |* Like and support open-source :) |
#
# **NOTE: You will still be able to run the whole notebook at your own pace and learn about these concepts along the way**
# **NOTE: If you just want run the code and start to play, please go to the challenge version 1, clean in the folder**
#
# ----

# %% [markdown]
# ⚠️ **In case of colab, before starting, make sure you're on a GPU instance for faster training!** ⚠️
#
# > If running on Google Colab, please request a GPU runtime by clicking `Runtime/Change runtime type` in the top bar menu, then selecting 'T4 GPU' under 'Hardware accelerator'.

# %%
# Identify whether a CUDA-enabled GPU is available
from pathlib import Path
import torch

device = "cuda" if torch.cuda.is_available() else "cpu"
if device == "cuda":
    msg ='CUDA-enabled GPU found. Training should be faster.'
else:
    msg = (
        "No GPU found. Training will be carried out on CPU, which might be "
        "slower.\n\nIf running on Google Colab, you can request a GPU runtime by"
        " clicking\n`Runtime/Change runtime type` in the top bar menu, then "
        "selecting \'T4 GPU\'\nunder \'Hardware accelerator\'."
    )
print(msg)
# Out:
# No GPU found. Training will be carried out on CPU, which might be slower.
#
# If running on Google Colab, you can request a GPU runtime by clicking
# `Runtime/Change runtime type` in the top bar menu, then selecting 'T4 GPU'
# under 'Hardware accelerator'.

# %% [markdown]
# For the challenge, we will need two significant dependencies: `braindecode` and `eegdash`. The libraries will install PyTorch, Pytorch Audio, Scikit-learn, MNE, MNE-BIDS, and many other packages necessary for the many functions.

# %%
#@title ▶️ Install additional required packages for colab
# !pip install braindecode
# !pip install eegdash
# Out:
# Requirement already satisfied: braindecode in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (1.0.0)
# Requirement already satisfied: mne>=1.10.0 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from braindecode) (1.10.1)
# Requirement already satisfied: mne_bids>=0.16 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from braindecode) (0.16.0)
# Requirement already satisfied: numpy in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from braindecode) (2.2.6)
# Requirement already satisfied: pandas in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from braindecode) (2.3.1)
# Requirement already satisfied: scipy in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from braindecode) (1.16.1)
# Requirement already satisfied: matplotlib in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from braindecode) (3.10.5)
# Requirement already satisfied: h5py in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from braindecode) (3.14.0)
# Requirement already satisfied: skorch in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from braindecode) (1.2.0)
# Requirement already satisfied: torch in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from braindecode) (2.8.0)
# Requirement already satisfied: torchaudio in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from braindecode) (2.8.0)
# Requirement already satisfied: einops in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from braindecode) (0.8.1)
# Requirement already satisfied: joblib in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from braindecode) (1.5.1)
# Requirement already satisfied: torchinfo in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from braindecode) (1.8.0)
# Requirement already satisfied: wfdb in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from braindecode) (4.3.0)
# Requirement already satisfied: linear_attention_transformer in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from braindecode) (0.19.1)
# Requirement already satisfied: docstring_inheritance in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from braindecode) (2.2.2)
# Requirement already satisfied: decorator in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from mne>=1.10.0->braindecode) (5.2.1)
# Requirement already satisfied: jinja2 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from mne>=1.10.0->braindecode) (3.1.6)
# Requirement already satisfied: lazy-loader>=0.3 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from mne>=1.10.0->braindecode) (0.4)
# Requirement already satisfied: packaging in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from mne>=1.10.0->braindecode) (25.0)
# Requirement already satisfied: pooch>=1.5 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from mne>=1.10.0->braindecode) (1.8.2)
# Requirement already satisfied: tqdm in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from mne>=1.10.0->braindecode) (4.67.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from matplotlib->braindecode) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from matplotlib->braindecode) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from matplotlib->braindecode) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from matplotlib->braindecode) (1.4.9)
# Requirement already satisfied: pillow>=8 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from matplotlib->braindecode) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from matplotlib->braindecode) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from matplotlib->braindecode) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5.0 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from pooch>=1.5->mne>=1.10.0->braindecode) (4.4.0)
# Requirement already satisfied: requests>=2.19.0 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from pooch>=1.5->mne>=1.10.0->braindecode) (2.32.4)
# Requirement already satisfied: six>=1.5 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->braindecode) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.5->mne>=1.10.0->braindecode) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.5->mne>=1.10.0->braindecode) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.5->mne>=1.10.0->braindecode) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.5->mne>=1.10.0->braindecode) (2025.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from jinja2->mne>=1.10.0->braindecode) (3.0.2)
# Requirement already satisfied: axial-positional-embedding in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from linear_attention_transformer->braindecode) (0.3.12)
# Requirement already satisfied: linformer>=0.1.0 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from linear_attention_transformer->braindecode) (0.2.3)
# Requirement already satisfied: local-attention in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from linear_attention_transformer->braindecode) (1.11.2)
# Requirement already satisfied: product-key-memory>=0.1.5 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from linear_attention_transformer->braindecode) (0.2.11)
# Requirement already satisfied: colt5-attention>=0.10.14 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from product-key-memory>=0.1.5->linear_attention_transformer->braindecode) (0.11.1)
# Requirement already satisfied: hyper-connections>=0.1.8 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from local-attention->linear_attention_transformer->braindecode) (0.2.1)
# Requirement already satisfied: filelock in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from torch->braindecode) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from torch->braindecode) (4.14.1)
# Requirement already satisfied: sympy>=1.13.3 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from torch->braindecode) (1.14.0)
# Requirement already satisfied: networkx in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from torch->braindecode) (3.5)
# Requirement already satisfied: fsspec in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from torch->braindecode) (2025.7.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from sympy>=1.13.3->torch->braindecode) (1.3.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from pandas->braindecode) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from pandas->braindecode) (2025.2)
# Requirement already satisfied: scikit-learn>=0.22.0 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from skorch->braindecode) (1.7.1)
# Requirement already satisfied: tabulate>=0.7.7 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from skorch->braindecode) (0.9.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from scikit-learn>=0.22.0->skorch->braindecode) (3.6.0)
# Requirement already satisfied: aiohttp>=3.10.11 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from wfdb->braindecode) (3.12.15)
# Requirement already satisfied: soundfile>=0.10.0 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from wfdb->braindecode) (0.13.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from aiohttp>=3.10.11->wfdb->braindecode) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from aiohttp>=3.10.11->wfdb->braindecode) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from aiohttp>=3.10.11->wfdb->braindecode) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from aiohttp>=3.10.11->wfdb->braindecode) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from aiohttp>=3.10.11->wfdb->braindecode) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from aiohttp>=3.10.11->wfdb->braindecode) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from aiohttp>=3.10.11->wfdb->braindecode) (1.20.1)
# Requirement already satisfied: cffi>=1.0 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from soundfile>=0.10.0->wfdb->braindecode) (1.17.1)
# Requirement already satisfied: pycparser in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from cffi>=1.0->soundfile>=0.10.0->wfdb->braindecode) (2.22)
# Requirement already satisfied: eegdash in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (0.3.6)
# Requirement already satisfied: braindecode>=1.0 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from eegdash) (1.0.0)
# Requirement already satisfied: mne_bids>=0.16.0 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from eegdash) (0.16.0)
# Requirement already satisfied: numba in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from eegdash) (0.61.2)
# Requirement already satisfied: numpy in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from eegdash) (2.2.6)
# Requirement already satisfied: pandas in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from eegdash) (2.3.1)
# Requirement already satisfied: pybids in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from eegdash) (0.19.0)
# Requirement already satisfied: pymongo in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from eegdash) (4.14.0)
# Requirement already satisfied: python-dotenv in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from eegdash) (1.1.1)
# Requirement already satisfied: s3fs in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from eegdash) (2025.7.0)
# Requirement already satisfied: scipy in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from eegdash) (1.16.1)
# Requirement already satisfied: tqdm in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from eegdash) (4.67.1)
# Requirement already satisfied: xarray in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from eegdash) (2025.7.1)
# Requirement already satisfied: h5io>=0.2.4 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from eegdash) (0.2.5)
# Requirement already satisfied: pymatreader in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from eegdash) (1.1.0)
# Requirement already satisfied: eeglabio in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from eegdash) (0.1.0)
# Requirement already satisfied: tabulate in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from eegdash) (0.9.0)
# Requirement already satisfied: mne>=1.10.0 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from braindecode>=1.0->eegdash) (1.10.1)
# Requirement already satisfied: matplotlib in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from braindecode>=1.0->eegdash) (3.10.5)
# Requirement already satisfied: h5py in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from braindecode>=1.0->eegdash) (3.14.0)
# Requirement already satisfied: skorch in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from braindecode>=1.0->eegdash) (1.2.0)
# Requirement already satisfied: torch in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from braindecode>=1.0->eegdash) (2.8.0)
# Requirement already satisfied: torchaudio in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from braindecode>=1.0->eegdash) (2.8.0)
# Requirement already satisfied: einops in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from braindecode>=1.0->eegdash) (0.8.1)
# Requirement already satisfied: joblib in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from braindecode>=1.0->eegdash) (1.5.1)
# Requirement already satisfied: torchinfo in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from braindecode>=1.0->eegdash) (1.8.0)
# Requirement already satisfied: wfdb in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from braindecode>=1.0->eegdash) (4.3.0)
# Requirement already satisfied: linear_attention_transformer in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from braindecode>=1.0->eegdash) (0.19.1)
# Requirement already satisfied: docstring_inheritance in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from braindecode>=1.0->eegdash) (2.2.2)
# Requirement already satisfied: decorator in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from mne>=1.10.0->braindecode>=1.0->eegdash) (5.2.1)
# Requirement already satisfied: jinja2 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from mne>=1.10.0->braindecode>=1.0->eegdash) (3.1.6)
# Requirement already satisfied: lazy-loader>=0.3 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from mne>=1.10.0->braindecode>=1.0->eegdash) (0.4)
# Requirement already satisfied: packaging in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from mne>=1.10.0->braindecode>=1.0->eegdash) (25.0)
# Requirement already satisfied: pooch>=1.5 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from mne>=1.10.0->braindecode>=1.0->eegdash) (1.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from matplotlib->braindecode>=1.0->eegdash) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from matplotlib->braindecode>=1.0->eegdash) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from matplotlib->braindecode>=1.0->eegdash) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from matplotlib->braindecode>=1.0->eegdash) (1.4.9)
# Requirement already satisfied: pillow>=8 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from matplotlib->braindecode>=1.0->eegdash) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from matplotlib->braindecode>=1.0->eegdash) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from matplotlib->braindecode>=1.0->eegdash) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5.0 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from pooch>=1.5->mne>=1.10.0->braindecode>=1.0->eegdash) (4.4.0)
# Requirement already satisfied: requests>=2.19.0 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from pooch>=1.5->mne>=1.10.0->braindecode>=1.0->eegdash) (2.32.4)
# Requirement already satisfied: six>=1.5 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->braindecode>=1.0->eegdash) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.5->mne>=1.10.0->braindecode>=1.0->eegdash) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.5->mne>=1.10.0->braindecode>=1.0->eegdash) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.5->mne>=1.10.0->braindecode>=1.0->eegdash) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.5->mne>=1.10.0->braindecode>=1.0->eegdash) (2025.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from jinja2->mne>=1.10.0->braindecode>=1.0->eegdash) (3.0.2)
# Requirement already satisfied: axial-positional-embedding in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from linear_attention_transformer->braindecode>=1.0->eegdash) (0.3.12)
# Requirement already satisfied: linformer>=0.1.0 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from linear_attention_transformer->braindecode>=1.0->eegdash) (0.2.3)
# Requirement already satisfied: local-attention in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from linear_attention_transformer->braindecode>=1.0->eegdash) (1.11.2)
# Requirement already satisfied: product-key-memory>=0.1.5 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from linear_attention_transformer->braindecode>=1.0->eegdash) (0.2.11)
# Requirement already satisfied: colt5-attention>=0.10.14 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from product-key-memory>=0.1.5->linear_attention_transformer->braindecode>=1.0->eegdash) (0.11.1)
# Requirement already satisfied: hyper-connections>=0.1.8 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from local-attention->linear_attention_transformer->braindecode>=1.0->eegdash) (0.2.1)
# Requirement already satisfied: filelock in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from torch->braindecode>=1.0->eegdash) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from torch->braindecode>=1.0->eegdash) (4.14.1)
# Requirement already satisfied: sympy>=1.13.3 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from torch->braindecode>=1.0->eegdash) (1.14.0)
# Requirement already satisfied: networkx in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from torch->braindecode>=1.0->eegdash) (3.5)
# Requirement already satisfied: fsspec in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from torch->braindecode>=1.0->eegdash) (2025.7.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from sympy>=1.13.3->torch->braindecode>=1.0->eegdash) (1.3.0)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from numba->eegdash) (0.44.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from pandas->eegdash) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from pandas->eegdash) (2025.2)
# Requirement already satisfied: nibabel>=4.0 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from pybids->eegdash) (5.3.2)
# Requirement already satisfied: formulaic>=0.3 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from pybids->eegdash) (1.2.0)
# Requirement already satisfied: sqlalchemy>=1.4.31 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from pybids->eegdash) (2.0.43)
# Requirement already satisfied: bids-validator>=1.14.7 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from pybids->eegdash) (1.14.7.post0)
# Requirement already satisfied: num2words>=0.5.10 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from pybids->eegdash) (0.5.14)
# Requirement already satisfied: click>=8.0 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from pybids->eegdash) (8.2.1)
# Requirement already satisfied: universal_pathlib>=0.2.2 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from pybids->eegdash) (0.2.6)
# Requirement already satisfied: frozendict>=2.3 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from pybids->eegdash) (2.4.6)
# Requirement already satisfied: bidsschematools>=0.10 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from bids-validator>=1.14.7->pybids->eegdash) (1.0.13)
# Requirement already satisfied: acres in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from bidsschematools>=0.10->bids-validator>=1.14.7->pybids->eegdash) (0.5.0)
# Requirement already satisfied: pyyaml in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from bidsschematools>=0.10->bids-validator>=1.14.7->pybids->eegdash) (6.0.2)
# Requirement already satisfied: interface-meta>=1.2.0 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from formulaic>=0.3->pybids->eegdash) (1.3.0)
# Requirement already satisfied: narwhals>=1.17 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from formulaic>=0.3->pybids->eegdash) (2.1.0)
# Requirement already satisfied: wrapt>=1.0 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from formulaic>=0.3->pybids->eegdash) (1.17.2)
# Requirement already satisfied: importlib-resources>=5.12 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from nibabel>=4.0->pybids->eegdash) (6.5.2)
# Requirement already satisfied: docopt>=0.6.2 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from num2words>=0.5.10->pybids->eegdash) (0.6.2)
# Requirement already satisfied: xmltodict in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from pymatreader->eegdash) (0.14.2)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from pymongo->eegdash) (2.7.0)
# Requirement already satisfied: aiobotocore<3.0.0,>=2.5.4 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from s3fs->eegdash) (2.24.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from s3fs->eegdash) (3.12.15)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->eegdash) (0.12.0)
# Requirement already satisfied: botocore<1.39.12,>=1.39.9 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->eegdash) (1.39.11)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->eegdash) (1.0.1)
# Requirement already satisfied: multidict<7.0.0,>=6.0.0 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->eegdash) (6.6.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->eegdash) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->eegdash) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->eegdash) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->eegdash) (1.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->eegdash) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->eegdash) (1.20.1)
# Requirement already satisfied: scikit-learn>=0.22.0 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from skorch->braindecode>=1.0->eegdash) (1.7.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from scikit-learn>=0.22.0->skorch->braindecode>=1.0->eegdash) (3.6.0)
# Requirement already satisfied: soundfile>=0.10.0 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from wfdb->braindecode>=1.0->eegdash) (0.13.1)
# Requirement already satisfied: cffi>=1.0 in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from soundfile>=0.10.0->wfdb->braindecode>=1.0->eegdash) (1.17.1)
# Requirement already satisfied: pycparser in /Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages (from cffi>=1.0->soundfile>=0.10.0->wfdb->braindecode>=1.0->eegdash) (2.22)

# %% [markdown]
# ## 1. What are we decoding?
#
# To start to talk about what we want to analyse, the important thing is to understand some basic concepts.
#
# -----
#
# # The brain decodes the problem
#
# Broadly speaking, here *brain decoding* is the following problem: given brain time-series signals $X \in \mathbb{R}^{C \times T}$ with labels $y \in \mathcal{Y}$, we implement a neural network $f$ that **decodes/translates** brain activity into the target label.
#
# We aim to translate recorded brain activity into its originating stimulus, behavior, or mental state, [King, J-R. et al. (2020)](https://lauragwilliams.github.io/d/m/CognitionAlgorithm.pdf).
#
# The neural network $f$ applies a series of transformation layers (e.g., `torch.nn.Conv2d`, `torch.nn.Linear`, `torch.nn.ELU`, `torch.nn.BatchNorm2d`) to the data to filter, extract features, and learn embeddings relevant to the optimization objective—in other words:
#
# $$
# f_{\theta}: X \to y,
# $$
#
# where $C$ (`n_chans`) is the number of channels/electrodes and $T$ (`n_times`) is the temporal window length/epoch size over the interval of interest. Here, $\theta$ denotes the parameters learned by the neural network.
#
#
# ----
#
# For the competition, the HBN-EEG (Healthy Brain Network EEG Datasets) dataset has `n_chans = 129` with the last channels as [reference channel](https://mne.tools/stable/auto_tutorials/preprocessing/55_setting_eeg_reference.html), and we define the window length as `n_times = 200`, corresponding to 2-second windows.
#
# Your model should follow this definition exactly; any specific selection of channels, filtering, or domain-adaptation technique must be performed **within the layers of the neural network model**.

# %% [markdown]
# ## 2. Contrast Change Detection (CCD) task
#
# In a more straightforward explanation for the machine learning audience, one person will execute one specific cognitive task during one period, and the brain signal is recorded, which encodes the brain dynamics that are happening during this moment.
#
# The Contrast Change Detection is type of cognitive task related to [Steady-State Visual Evoked Potential](en.wikipedia.org/wiki/Steady_state_visually_evoked_potential) - SSVEP and [Event-Related Potential](https://en.wikipedia.org/wiki/Event-related_potential) - ERP components.
#
# Algorithmically describing what the subject is sees during a brain scan recording is:
#
# * They see two flickering striped discs: one tilted left, one tilted right.
# * After a random delay, **one disc’s contrast briefly increases**.
# * They **press left or right** to indicate which disc changed.
# * They get **feedback** ( 🙂 correct / 🙁 incorrect ).
#
# **The task has parallel with SSVEP and ERP:**
#
# * The continuous flicker **tags the EEG with steady frequencies**, i.e, SSVEP-like signals.
# * The sudden contrast change, the **button press**, and the **feedback** are **time-locked events** that produce ERP-like components.
#
# So CCD mixes **frequency-based (SSVEP)** and **event-locked (ERP)** information, and the brain recorded have this information encoded that somehow that we need decipher.
#
# In the Video, we have an example of recording cognitive activity:

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("tOW2Vu2zHoU", start=1630, width=960, height=540)

# %% [markdown]
# In the figure below, we have the timeline representation of the cognitive task:
#
# ![https://eeg2025.github.io/assets/img/CCD_sequence.png](https://eeg2025.github.io/assets/img/image-2.jpg)

# %% [markdown]
# Now, talking about the code, we can start to use `eegdash`!

# %%
from pathlib import Path

DATA_DIR = Path("data")
DATA_DIR.mkdir(parents=True, exist_ok=True)

from eegdash.dataset import EEGChallengeDataset

dataset_ccd = EEGChallengeDataset(task="contrastChangeDetection", 
                                  release="R5", cache_dir=DATA_DIR,
                                  mini=True)

# %% [markdown]
# Now, we have a Pytorch Dataset object that contains the set of recordings for the task `contrastChangeDetection`.
#
# This dataset object have very rich Raw object details that can help you to understand better the data. The framework behind this is braindecode, and if you want to understand in depth what is happening, we recommend the braindecode github itself.

# %% [markdown]
# If you want to load the whole release you need change the `mini=False`.

# %%
# For visualization purposes, we will see just one object.

raw = dataset_ccd.datasets[0].raw  # get the Raw object of the first recording

# %%
fig = raw.plot()
# Out:
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %% [markdown]
# As you just realized, the eeg dash dataset object will download the dataset only when necessary, and in this case, only when we want to consume the raw data. To download all data directly, we recommend downloading the versions with Amazon API, or doing something like:

# %%
from joblib import Parallel, delayed

raws = Parallel(n_jobs=-1)(
    delayed(lambda d: d.raw)(d) for d in dataset_ccd.datasets
)

# %% [markdown]
# ## 2. Creating the windows of interest
#
# Now that we have our raw dataset, defining the windows/epoch interval is essential.
#
# For this challenge, we test many different and semantically different regions of interest, and our preliminary studies show us that the most interesting area of interest is defined below:
#
#
# *        stimulus         │        response         │        feedback
# *                         │ *********************** (stimulus + 0.5)
#
# So we epoch after the stimulus moment with a beginning shift of 500 ms.

# %%
#@title ▶️ Run this first to get all the utils functions for the epoching
import numpy as np
import pandas as pd
import mne
from mne_bids import get_bids_path_from_fname
from braindecode.datasets import BaseConcatDataset

# extract evets:
def build_trial_table(events_df: pd.DataFrame) -> pd.DataFrame:
    """One row per contrast trial with stimulus/response metrics."""
    events_df = events_df.copy()
    events_df["onset"] = pd.to_numeric(events_df["onset"], errors="raise")
    events_df = events_df.sort_values("onset", kind="mergesort").reset_index(drop=True)

    trials = events_df[events_df["value"].eq("contrastTrial_start")].copy()
    stimuli = events_df[events_df["value"].isin(["left_target", "right_target"])].copy()
    responses = events_df[events_df["value"].isin(["left_buttonPress", "right_buttonPress"])].copy()

    trials = trials.reset_index(drop=True)
    trials["next_onset"] = trials["onset"].shift(-1)
    trials = trials.dropna(subset=["next_onset"]).reset_index(drop=True)

    rows = []
    for _, tr in trials.iterrows():
        start = float(tr["onset"])
        end   = float(tr["next_onset"])

        stim_block = stimuli[(stimuli["onset"] >= start) & (stimuli["onset"] < end)]
        stim_onset = np.nan if stim_block.empty else float(stim_block.iloc[0]["onset"])

        if not np.isnan(stim_onset):
            resp_block = responses[(responses["onset"] >= stim_onset) & (responses["onset"] < end)]
        else:
            resp_block = responses[(responses["onset"] >= start) & (responses["onset"] < end)]

        if resp_block.empty:
            resp_onset = np.nan
            resp_type  = None
            feedback   = None
        else:
            resp_onset = float(resp_block.iloc[0]["onset"])
            resp_type  = resp_block.iloc[0]["value"]
            feedback   = resp_block.iloc[0]["feedback"]

        rt_from_stim  = (resp_onset - stim_onset) if (not np.isnan(stim_onset) and not np.isnan(resp_onset)) else np.nan
        rt_from_trial = (resp_onset - start)       if not np.isnan(resp_onset) else np.nan

        correct = None
        if isinstance(feedback, str):
            if feedback == "smiley_face": correct = True
            elif feedback == "sad_face":  correct = False

        rows.append({
            "trial_start_onset": start,
            "trial_stop_onset": end,
            "stimulus_onset": stim_onset,
            "response_onset": resp_onset,
            "rt_from_stimulus": rt_from_stim,
            "rt_from_trialstart": rt_from_trial,
            "response_type": resp_type,
            "correct": correct,
        })

    return pd.DataFrame(rows)

# Aux functions to inject the annot
def _to_float_or_none(x):
    return None if pd.isna(x) else float(x)

def _to_int_or_none(x):
    if pd.isna(x):
        return None
    if isinstance(x, (bool, np.bool_)):
        return int(bool(x))
    if isinstance(x, (int, np.integer)):
        return int(x)
    try:
        return int(x)
    except Exception:
        return None

def _to_str_or_none(x):
    return None if (x is None or (isinstance(x, float) and np.isnan(x))) else str(x)

def annotate_trials_with_target(raw, target_field="rt_from_stimulus", epoch_length=2.0,
                                require_stimulus=True, require_response=True):
    """Create 'contrast_trial_start' annotations with float target in extras."""
    fnames = raw.filenames
    assert len(fnames) == 1, "Expected a single filename"
    bids_path = get_bids_path_from_fname(fnames[0])
    events_file = bids_path.update(suffix="events", extension=".tsv").fpath

    events_df = (pd.read_csv(events_file, sep="\t")
                   .assign(onset=lambda d: pd.to_numeric(d["onset"], errors="raise"))
                   .sort_values("onset", kind="mergesort").reset_index(drop=True))

    trials = build_trial_table(events_df)

    if require_stimulus:
        trials = trials[trials["stimulus_onset"].notna()].copy()
    if require_response:
        trials = trials[trials["response_onset"].notna()].copy()

    if target_field not in trials.columns:
        raise KeyError(f"{target_field} not in computed trial table.")
    targets = trials[target_field].astype(float)

    onsets     = trials["trial_start_onset"].to_numpy(float)
    durations  = np.full(len(trials), float(epoch_length), dtype=float)
    descs      = ["contrast_trial_start"] * len(trials)

    extras = []
    for i, v in enumerate(targets):
        row = trials.iloc[i]

        extras.append({
            "target": _to_float_or_none(v),
            "rt_from_stimulus": _to_float_or_none(row["rt_from_stimulus"]),
            "rt_from_trialstart": _to_float_or_none(row["rt_from_trialstart"]),
            "stimulus_onset": _to_float_or_none(row["stimulus_onset"]),
            "response_onset": _to_float_or_none(row["response_onset"]),
            "correct": _to_int_or_none(row["correct"]),
            "response_type": _to_str_or_none(row["response_type"]),
        })

    new_ann = mne.Annotations(onset=onsets, duration=durations, description=descs,
                              orig_time=raw.info["meas_date"], extras=extras)
    raw.set_annotations(new_ann, verbose=False)
    return raw

# %% ------------------------------------ Add stimulus/response anchor events
def add_aux_anchors(raw, stim_desc="stimulus_anchor", resp_desc="response_anchor"):
    ann = raw.annotations
    mask = (ann.description == "contrast_trial_start")
    if not np.any(mask):
        return raw

    stim_onsets, resp_onsets = [], []
    stim_extras, resp_extras = [], []

    for idx in np.where(mask)[0]:
        ex = ann.extras[idx] if ann.extras is not None else {}
        t0 = float(ann.onset[idx])

        stim_t = ex["stimulus_onset"] 
        resp_t = ex["response_onset"] 

        if stim_t is None or (isinstance(stim_t, float) and np.isnan(stim_t)):
            rtt = ex["rt_from_trialstart"]
            rts = ex["rt_from_stimulus"]
            if rtt is not None and rts is not None:
                stim_t = t0 + float(rtt) - float(rts)

        if resp_t is None or (isinstance(resp_t, float) and np.isnan(resp_t)):
            rtt = ex["rt_from_trialstart"]
            if rtt is not None:
                resp_t = t0 + float(rtt)

        if (stim_t is not None) and not (isinstance(stim_t, float) and np.isnan(stim_t)):
            stim_onsets.append(float(stim_t))
            stim_extras.append(dict(ex, anchor="stimulus"))
        if (resp_t is not None) and not (isinstance(resp_t, float) and np.isnan(resp_t)):
            resp_onsets.append(float(resp_t))
            resp_extras.append(dict(ex, anchor="response"))

    new_onsets = np.array(stim_onsets + resp_onsets, dtype=float)
    if len(new_onsets):
        aux = mne.Annotations(
            onset=new_onsets,
            duration=np.zeros_like(new_onsets, dtype=float),
            description=[stim_desc]*len(stim_onsets) + [resp_desc]*len(resp_onsets),
            orig_time=raw.info["meas_date"],
            extras=stim_extras + resp_extras,
        )
        raw.set_annotations(ann + aux, verbose=False)
    return raw


def add_extras_columns(
    windows_concat_ds,
    original_concat_ds,
    desc="contrast_trial_start",
    keys=("target","rt_from_stimulus","rt_from_trialstart","stimulus_onset","response_onset","correct","response_type"),
):
    float_cols = {"target","rt_from_stimulus","rt_from_trialstart","stimulus_onset","response_onset"}

    for win_ds, base_ds in zip(windows_concat_ds.datasets, original_concat_ds.datasets):
        ann = base_ds.raw.annotations
        idx = np.where(ann.description == desc)[0]
        if idx.size == 0:
            continue

        per_trial = [
            {k: (ann.extras[i][k] if ann.extras is not None and k in ann.extras[i] else None) for k in keys}
            for i in idx
        ]

        md = win_ds.metadata.copy()
        first = (md["i_window_in_trial"].to_numpy() == 0)
        trial_ids = first.cumsum() - 1
        n_trials = trial_ids.max() + 1 if len(trial_ids) else 0
        assert n_trials == len(per_trial), f"Trial mismatch: {n_trials} vs {len(per_trial)}"

        for k in keys:
            vals = [per_trial[t][k] if t < len(per_trial) else None for t in trial_ids]
            if k == "correct":
                ser = pd.Series([None if v is None else int(bool(v)) for v in vals],
                                index=md.index, dtype="Int64")
            elif k in float_cols:
                ser = pd.Series([np.nan if v is None else float(v) for v in vals],
                                index=md.index, dtype="Float64")
            else:  # response_type
                ser = pd.Series(vals, index=md.index, dtype="string")

            # Replace the whole column to avoid dtype conflicts
            md[k] = ser

        win_ds.metadata = md.reset_index(drop=True)
        if hasattr(win_ds, "y"):
            y_np = win_ds.metadata["target"].astype(float).to_numpy()
            win_ds.y = y_np[:, None]  # (N, 1)

    return windows_concat_ds

# %% ------------------------------------ Utility: keep recordings that have a given event
def keep_only_recordings_with(desc, concat_ds):
    kept = []
    for ds in concat_ds.datasets:
        if np.any(ds.raw.annotations.description == desc):
            kept.append(ds)
        else:
            print(f"[warn] Recording {ds.raw.filenames[0]} does not contain event '{desc}'")
    return BaseConcatDataset(kept)

# %% [markdown]
# So, on our raw data, we fit the events present in it, and create a window of interest.

# %%
from braindecode.preprocessing import preprocess, Preprocessor, create_windows_from_events

EPOCH_LEN_S = 2.0
SFREQ = 100 # by definition here

transformation_offline = [
    Preprocessor(
        annotate_trials_with_target,
        target_field="rt_from_stimulus", epoch_length=EPOCH_LEN_S,
        require_stimulus=True, require_response=True,
        apply_on_array=False,
    ),
    Preprocessor(add_aux_anchors, apply_on_array=False),
]
preprocess(dataset_ccd, transformation_offline, n_jobs=1)

ANCHOR = "stimulus_anchor"

SHIFT_AFTER_STIM = 0.5  
WINDOW_LEN       = 2.0 

# Keep only recordings that actually contain stimulus anchors
dataset = keep_only_recordings_with(ANCHOR, dataset_ccd)

# Create single-interval windows (stim-locked, long enough to include the response)
single_windows = create_windows_from_events(
    dataset,
    mapping={ANCHOR: 0},
    trial_start_offset_samples=int(SHIFT_AFTER_STIM * SFREQ),                 # +0.5 s
    trial_stop_offset_samples=int((SHIFT_AFTER_STIM + WINDOW_LEN) * SFREQ),   # +2.5 s
    window_size_samples=int(EPOCH_LEN_S * SFREQ),
    window_stride_samples=SFREQ, 
    preload=True,
)

# Injecting metadata into the extra mne annotation.
single_windows = add_extras_columns(
    single_windows,
    dataset,
    desc=ANCHOR,
    keys=("target", "rt_from_stimulus", "rt_from_trialstart",
          "stimulus_onset", "response_onset", "correct", "response_type")
          )
# Out:
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]
# Used Annotations descriptions: [np.str_('stimulus_anchor')]

# %% [markdown]
# Now that we have our windowed data, we can split it into the different sets that are needed for modeling. Since our challenge focuses on generalization across subjects, we recommend dividing at the subject level.
#
# (1) the training set is used to learn the parameters of our deep learning model,
#
# (2) the validation set is used to monitor the training process and decide when to stop it, and
#
# (3) the test set is used to provide an estimate of the generalization performance of our model.
#
# Here, we use the last 10% of windows for testing, 10% for validation and split the remaining 80% of windows into training.
#
# **Here we go into the steps that you and your team must validate to obtain better results**

# %%
# for each windows, we can extract the metainformation using:

meta_information = single_windows.get_metadata()

# %%
meta_information.head()
# Out:
#    i_window_in_trial  i_start_in_trial  i_stop_in_trial  target  \
# 0                  0             11056            11256    2.11
# 1                  0             11579            11779    1.87
# 2                  0             12259            12459    1.95
# 3                  0             13099            13299     2.1
# 4                  0             13619            13819    1.22
#
#    rt_from_stimulus  rt_from_trialstart  stimulus_onset  response_onset  \
# 0              2.11               4.932         110.062         112.172
# 1              1.87               4.672          115.29          117.16
# 2              1.95                6.35          122.09          124.04
# 3               2.1                 8.1          130.49          132.59
# 4              1.22                4.02          135.69          136.91
#
#    correct      response_type       subject  run                     task  \
# 0        1  right_buttonPress  NDARAH793FBF    1  contrastChangeDetection
# 1        1  right_buttonPress  NDARAH793FBF    1  contrastChangeDetection
# 2        1  right_buttonPress  NDARAH793FBF    1  contrastChangeDetection
# 3        1  right_buttonPress  NDARAH793FBF    1  contrastChangeDetection
# 4        1   left_buttonPress  NDARAH793FBF    1  contrastChangeDetection
#
#       age sex
# 0  9.3427   M
# 1  9.3427   M
# 2  9.3427   M
# 3  9.3427   M
# 4  9.3427   M

# %%
from sklearn.model_selection import train_test_split
from sklearn.utils import check_random_state

valid_frac = 0.1
test_frac = 0.1
seed = 2025

subjects = meta_information["subject"].unique()

train_subj, valid_test_subject = train_test_split(
    subjects, test_size=(valid_frac + test_frac), random_state=check_random_state(seed), shuffle=True
)

valid_subj, test_subj = train_test_split(
    valid_test_subject, test_size=test_frac, random_state=check_random_state(seed + 1), shuffle=True
)
# sanity check
assert (set(valid_subj) | set(test_subj) | set(train_subj)) == set(subjects)

# %%
# now we need to create the train/valid/test splits for the windows
train_idx = meta_information[meta_information["subject"].isin(train_subj)].index
valid_idx = meta_information[meta_information["subject"].isin(valid_subj)].index
test_idx = meta_information[meta_information["subject"].isin(test_subj)].index

# and finally using braindecode split function, we can do:
subject_split = single_windows.split("subject")
train_set = []
valid_set = []
test_set = []

for s in subject_split:
    if s in train_subj:
        train_set.append(subject_split[s])
    elif s in valid_subj:
        valid_set.append(subject_split[s])
    elif s in test_subj:
        test_set.append(subject_split[s])

train_set = BaseConcatDataset(train_set)
valid_set = BaseConcatDataset(valid_set)
test_set = BaseConcatDataset(test_set)

print("Number of examples in each split in the minirelease")
print(f"Train:\t{len(train_set)}")
print(f"Valid:\t{len(valid_set)}")
print(f"Test:\t{len(test_set)}")
# Out:
# Number of examples in each split in the minirelease
# Train:	981
# Valid:	183
# Test:	50

# %% [markdown]
# Finally, we create pytorch `DataLoader`s, which will be used to feed the data to the model during training and evaluation:

# %%
# Create datasets and dataloaders
from torch.utils.data import DataLoader

batch_size = 128
num_workers = 2

train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True, num_workers=num_workers)
valid_loader = DataLoader(valid_set, batch_size=batch_size, shuffle=False, num_workers=num_workers)
test_loader = DataLoader(test_set, batch_size=batch_size, shuffle=False, num_workers=num_workers)

# %% [markdown]
# ## Building the deep learning model
#
# For neural network models, we employ [braindecode model's](https://braindecode.org/1.2/models/models_table.html) zoo, at the library, we have implemented several different models for decoding the brain timeseries.

# %%
from braindecode.models.util import models_dict

names = sorted(models_dict)
w = max(len(n) for n in names) 

for i in range(0, len(names), 3):
    row = names[i:i+3]
    print("  ".join(f"{n:<{w}}" for n in row))
# Out:
# ATCNet                  AttentionBaseNet        BDTCN
# BIOT                    CTNet                   ContraWR
# Deep4Net                DeepSleepNet            EEGConformer
# EEGITNet                EEGInceptionERP         EEGInceptionMI
# EEGMiner                EEGNeX                  EEGNetv1
# EEGNetv4                EEGResNet               EEGSimpleConv
# EEGTCNet                FBCNet                  FBLightConvNet
# FBMSNet                 IFNet                   Labram
# MSVTNet                 SCCNet                  SPARCNet
# ShallowFBCSPNet         SignalJEPA              SignalJEPA_Contextual
# SignalJEPA_PostLocal    SignalJEPA_PreLocal     SincShallowNet
# SleepStagerBlanco2020   SleepStagerChambon2018  SleepStagerEldele2021
# SyncNet                 TIDNet                  TSceptionV1
# USleep

# %%
# for any braindecode model, you can initialize only inputing the signal related parameters
from braindecode.models import EEGNeX

model = EEGNeX(n_chans=129, # 129 channels
                n_outputs=1, # 1 output for regression
                n_times=200, #2 seconds
                sfreq=100,      # sample frequency 100 Hz
                )

# %%
# the braindecode models have this convenient way to initialize with just the signal parameters
# and also some eegmodulemixin that allow to easily torch info once the model is created

print(model)
# Out:
# ================================================================================================================================================================
# Layer (type (var_name):depth-idx)                            Input Shape               Output Shape              Param #                   Kernel Shape
# ================================================================================================================================================================
# EEGNeX (EEGNeX)                                              [1, 129, 200]             [1, 1]                    --                        --
# ├─Sequential (block_1): 1-1                                  [1, 129, 200]             [1, 8, 129, 200]          --                        --
# │    └─Rearrange (0): 2-1                                    [1, 129, 200]             [1, 1, 129, 200]          --                        --
# │    └─Conv2d (1): 2-2                                       [1, 1, 129, 200]          [1, 8, 129, 200]          512                       [1, 64]
# │    └─BatchNorm2d (2): 2-3                                  [1, 8, 129, 200]          [1, 8, 129, 200]          16                        --
# ├─Sequential (block_2): 1-2                                  [1, 8, 129, 200]          [1, 32, 129, 200]         --                        --
# │    └─Conv2d (0): 2-4                                       [1, 8, 129, 200]          [1, 32, 129, 200]         16,384                    [1, 64]
# │    └─BatchNorm2d (1): 2-5                                  [1, 32, 129, 200]         [1, 32, 129, 200]         64                        --
# ├─Sequential (block_3): 1-3                                  [1, 32, 129, 200]         [1, 64, 1, 50]            --                        --
# │    └─ParametrizedConv2dWithConstraint (0): 2-6             [1, 32, 129, 200]         [1, 64, 1, 200]           --                        [129, 1]
# │    │    └─ModuleDict (parametrizations): 3-1               --                        --                        8,256                     --
# │    └─BatchNorm2d (1): 2-7                                  [1, 64, 1, 200]           [1, 64, 1, 200]           128                       --
# │    └─ELU (2): 2-8                                          [1, 64, 1, 200]           [1, 64, 1, 200]           --                        --
# │    └─AvgPool2d (3): 2-9                                    [1, 64, 1, 200]           [1, 64, 1, 50]            --                        [1, 4]
# │    └─Dropout (4): 2-10                                     [1, 64, 1, 50]            [1, 64, 1, 50]            --                        --
# ├─Sequential (block_4): 1-4                                  [1, 64, 1, 50]            [1, 32, 1, 50]            --                        --
# │    └─Conv2d (0): 2-11                                      [1, 64, 1, 50]            [1, 32, 1, 50]            32,768                    [1, 16]
# │    └─BatchNorm2d (1): 2-12                                 [1, 32, 1, 50]            [1, 32, 1, 50]            64                        --
# ├─Sequential (block_5): 1-5                                  [1, 32, 1, 50]            [1, 48]                   --                        --
# │    └─Conv2d (0): 2-13                                      [1, 32, 1, 50]            [1, 8, 1, 50]             4,096                     [1, 16]
# │    └─BatchNorm2d (1): 2-14                                 [1, 8, 1, 50]             [1, 8, 1, 50]             16                        --
# │    └─ELU (2): 2-15                                         [1, 8, 1, 50]             [1, 8, 1, 50]             --                        --
# │    └─AvgPool2d (3): 2-16                                   [1, 8, 1, 50]             [1, 8, 1, 6]              --                        [1, 8]
# │    └─Dropout (4): 2-17                                     [1, 8, 1, 6]              [1, 8, 1, 6]              --                        --
# │    └─Flatten (5): 2-18                                     [1, 8, 1, 6]              [1, 48]                   --                        --
# ├─ParametrizedLinearWithConstraint (final_layer): 1-6        [1, 48]                   [1, 1]                    1                         --
# │    └─ModuleDict (parametrizations): 2-19                   --                        --                        --                        --
# │    │    └─ParametrizationList (weight): 3-2                --                        [1, 48]                   48                        --
# ================================================================================================================================================================
# Total params: 62,353
# Trainable params: 62,353
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 437.76
# ================================================================================================================================================================
# Input size (MB): 0.10
# Forward/backward pass size (MB): 16.65
# Params size (MB): 0.22
# Estimated Total Size (MB): 16.97
# ================================================================================================================================================================

# %% [markdown]
# ### The rest is our classic PyTorch/torch lighting/skorch training pipeline

# %%
# Defining training parameters

lr = 1E-3
weight_decay = 1E-5
n_epochs = 100
early_stopping_patience = 50

# %%
from typing import Optional
import torch
from torch.utils.data import DataLoader
from tqdm import tqdm
from torch.nn import Module
from torch.optim.lr_scheduler import LRScheduler

# Define a method for training one epoch
def train_one_epoch(
    dataloader: DataLoader,
    model: Module,
    loss_fn,
    optimizer,
    scheduler: Optional[LRScheduler],
    epoch: int,
    device,
    print_batch_stats: bool = True,
):
    model.train()

    total_loss = 0.0
    sum_sq_err = 0.0
    n_samples = 0

    progress_bar = tqdm(
        enumerate(dataloader), total=len(dataloader), disable=not print_batch_stats
    )

    for batch_idx, batch in progress_bar:
        # Support datasets that may return (X, y) or (X, y, ...)
        X, y = batch[0], batch[1]
        X, y = X.to(device).float(), y.to(device).float()

        optimizer.zero_grad(set_to_none=True)
        preds = model(X)
        loss = loss_fn(preds, y)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

        # Flatten to 1D for regression metrics and accumulate squared error
        preds_flat = preds.detach().view(-1)
        y_flat = y.detach().view(-1)
        sum_sq_err += torch.sum((preds_flat - y_flat) ** 2).item()
        n_samples += y_flat.numel()

        if print_batch_stats:
            running_rmse = (sum_sq_err / max(n_samples, 1)) ** 0.5
            progress_bar.set_description(
                f"Epoch {epoch}, Batch {batch_idx + 1}/{len(dataloader)}, "
                f"Loss: {loss.item():.6f}, RMSE: {running_rmse:.6f}"
            )

    if scheduler is not None:
        scheduler.step()

    avg_loss = total_loss / len(dataloader)
    rmse = (sum_sq_err / max(n_samples, 1)) ** 0.5
    return avg_loss, rmse

# %%
import torch
from torch.utils.data import DataLoader
from torch.nn import Module
from tqdm import tqdm

@torch.no_grad()
def valid_model(
    dataloader: DataLoader,
    model: Module,
    loss_fn,
    device,
    print_batch_stats: bool = True,
):
    model.eval()

    total_loss = 0.0
    sum_sq_err = 0.0
    n_batches = len(dataloader)
    n_samples = 0

    iterator = tqdm(
        enumerate(dataloader),
        total=n_batches,
        disable=not print_batch_stats
    )

    for batch_idx, batch in iterator:
        # Supports (X, y) or (X, y, ...)
        X, y = batch[0], batch[1]
        X, y = X.to(device).float(), y.to(device).float()
        # casting X to float32
        
        preds = model(X)
        batch_loss = loss_fn(preds, y).item()
        total_loss += batch_loss

        preds_flat = preds.detach().view(-1)
        y_flat = y.detach().view(-1)
        sum_sq_err += torch.sum((preds_flat - y_flat) ** 2).item()
        n_samples += y_flat.numel()

        if print_batch_stats:
            running_rmse = (sum_sq_err / max(n_samples, 1)) ** 0.5
            iterator.set_description(
                f"Val Batch {batch_idx + 1}/{n_batches}, "
                f"Loss: {batch_loss:.6f}, RMSE: {running_rmse:.6f}"
            )

    avg_loss = total_loss / n_batches if n_batches else float("nan")
    rmse = (sum_sq_err / max(n_samples, 1)) ** 0.5

    print(f"Val RMSE: {rmse:.6f}, Val Loss: {avg_loss:.6f}\n")
    return avg_loss, rmse

# %%
import copy

optimizer = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=n_epochs - 1)
loss_fn = torch.nn.MSELoss()

patience = 5
min_delta = 1e-4
best_rmse = float("inf")
epochs_no_improve = 0
best_state, best_epoch = None, None

for epoch in range(1, n_epochs + 1):
    print(f"Epoch {epoch}/{n_epochs}: ", end="")

    train_loss, train_rmse = train_one_epoch(
        train_loader, model, loss_fn, optimizer, scheduler, epoch, device
    )
    val_loss, val_rmse = valid_model(test_loader, model, loss_fn, device)

    print(
        f"Train RMSE: {train_rmse:.6f}, "
        f"Average Train Loss: {train_loss:.6f}, "
        f"Val RMSE: {val_rmse:.6f}, "
        f"Average Val Loss: {val_loss:.6f}"
    )

    if val_rmse < best_rmse - min_delta:
        best_rmse = val_rmse
        best_state = copy.deepcopy(model.state_dict())
        best_epoch = epoch
        epochs_no_improve = 0
    else:
        epochs_no_improve += 1
        if epochs_no_improve >= patience:
            print(f"Early stopping at epoch {epoch}. Best Val RMSE: {best_rmse:.6f} (epoch {best_epoch})")
            break

if best_state is not None:
    model.load_state_dict(best_state)
# Out:
# Epoch 1/100:
# Epoch 1, Batch 8/8, Loss: 2.246979, RMSE: 1.504884: 100%|██████████| 8/8 [00:20<00:00,  2.61s/it]
#   0%|          | 0/1 [00:00<?, ?it/s]Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/multiprocessing/spawn.py", line 120, in spawn_main
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/multiprocessing/spawn.py", line 120, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/multiprocessing/spawn.py", line 130, in _main
#     exitcode = _main(fd, parent_sentinel)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/multiprocessing/spawn.py", line 130, in _main
#     self = reduction.pickle.load(from_parent)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/braindecode/__init__.py", line 1, in <module>
#     self = reduction.pickle.load(from_parent)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/braindecode/__init__.py", line 1, in <module>
#     from .classifier import EEGClassifier
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/braindecode/classifier.py", line 17, in <module>
#     from .classifier import EEGClassifier
#     from .eegneuralnet import _EEGNeuralNet
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/braindecode/classifier.py", line 17, in <module>
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/braindecode/eegneuralnet.py", line 21, in <module>
#   0%|          | 0/1 [00:01<?, ?it/s]    from .eegneuralnet import _EEGNeuralNet
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/braindecode/eegneuralnet.py", line 21, in <module>
#     from .models.util import models_dict
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/braindecode/models/__init__.py", line 5, in <module>
#     from .models.util import models_dict
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/braindecode/models/__init__.py", line 5, in <module>
#     from .atcnet import ATCNet
#     from .atcnet import ATCNet
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/braindecode/models/atcnet.py", line 7, in <module>
#     from einops.layers.torch import Rearrange
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/einops/layers/torch.py", line 7, in <module>
#     from .._torch_specific import apply_for_scriptable_torch
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/einops/_torch_specific.py", line 128, in <module>
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/braindecode/models/atcnet.py", line 7, in <module>
#     from einops.layers.torch import Rearrange
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/einops/layers/torch.py", line 7, in <module>
#     from .._torch_specific import apply_for_scriptable_torch
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/einops/_torch_specific.py", line 128, in <module>
#     allow_ops_in_compiled_graph()
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/einops/_torch_specific.py", line 107, in allow_ops_in_compiled_graph
#     from torch._dynamo import allow_in_graph
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/torch/_dynamo/__init__.py", line 13, in <module>
#     from . import config, convert_frame, eval_frame, resume_execution
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/torch/_dynamo/convert_frame.py", line 53, in <module>
#     from torch._dynamo.symbolic_convert import TensorifyState
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/torch/_dynamo/symbolic_convert.py", line 58, in <module>
#     from . import (
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/torch/_dynamo/trace_rules.py", line 56, in <module>
#     allow_ops_in_compiled_graph()
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/einops/_torch_specific.py", line 107, in allow_ops_in_compiled_graph
#     from torch._dynamo import allow_in_graph
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/torch/_dynamo/__init__.py", line 13, in <module>
#     from . import config, convert_frame, eval_frame, resume_execution
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/torch/_dynamo/convert_frame.py", line 53, in <module>
#     from .variables import (
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/torch/_dynamo/variables/__init__.py", line 19, in <module>
#     from torch._dynamo.symbolic_convert import TensorifyState
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/torch/_dynamo/symbolic_convert.py", line 58, in <module>
#     from . import (
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/torch/_dynamo/trace_rules.py", line 56, in <module>
#     from .variables import (
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/torch/_dynamo/variables/__init__.py", line 19, in <module>
#     from .base import VariableTracker
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/torch/_dynamo/variables/base.py", line 642, in <module>
#     from . import builder
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/torch/_dynamo/variables/builder.py", line 93, in <module>
#     from ..side_effects import SideEffects
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/torch/_dynamo/side_effects.py", line 44, in <module>
#         from .codegen import PyCodegenfrom .base import VariableTracker
#
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/torch/_dynamo/codegen.py", line 43, in <module>
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/torch/_dynamo/variables/base.py", line 642, in <module>
#     from . import builder
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/torch/_dynamo/variables/builder.py", line 93, in <module>
#     from ..side_effects import SideEffects
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/torch/_dynamo/side_effects.py", line 44, in <module>
#     from .variables.functions import (
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/torch/_dynamo/variables/functions.py", line 81, in <module>
#     from .codegen import PyCodegen
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/torch/_dynamo/codegen.py", line 43, in <module>
#     from .variables.functions import (
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/torch/_dynamo/variables/functions.py", line 81, in <module>
#     from torch.distributed.fsdp._fully_shard import _fsdp_param_group
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/torch/distributed/fsdp/__init__.py", line 1, in <module>
#     from torch.distributed.fsdp._fully_shard import _fsdp_param_group
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/torch/distributed/fsdp/__init__.py", line 1, in <module>
#     from ._flat_param import FlatParameter as FlatParameter
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/torch/distributed/fsdp/_flat_param.py", line 33, in <module>
#     from ._fsdp_extensions import (
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/torch/distributed/fsdp/_fsdp_extensions.py", line 8, in <module>
#     from ._flat_param import FlatParameter as FlatParameter
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/torch/distributed/fsdp/_flat_param.py", line 33, in <module>
#     from ._fsdp_extensions import (
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/torch/distributed/fsdp/_fsdp_extensions.py", line 8, in <module>
#     from torch.distributed.fsdp._shard_utils import (
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/torch/distributed/fsdp/_shard_utils.py", line 18, in <module>
#     from torch.distributed.tensor import DeviceMesh, DTensor, Replicate, Shard as DShard
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/torch/distributed/tensor/__init__.py", line 4, in <module>
#     import torch.distributed.tensor._ops  # force import all built-in dtensor ops
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/torch/distributed/tensor/_ops/__init__.py", line 2, in <module>
#     from ._conv_ops import *  # noqa: F403
#     ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/torch/distributed/tensor/_ops/_conv_ops.py", line 5, in <module>
#     from torch.distributed.tensor._dtensor_spec import DTensorSpec, TensorMeta
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/torch/distributed/tensor/_dtensor_spec.py", line 6, in <module>
#     from torch.distributed.tensor.placement_types import (
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/torch/distributed/tensor/placement_types.py", line 10, in <module>
#     from torch.distributed.tensor._collective_utils import (
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/torch/distributed/tensor/_collective_utils.py", line 30, in <module>
#     @torch.library.register_fake("_dtensor::shard_dim_alltoall")
#      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/torch/library.py", line 1069, in register
#     use_lib._register_fake(
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/torch/library.py", line 198, in _register_fake
#     source = torch._library.utils.get_source(_stacklevel + 1)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/torch/_library/utils.py", line 54, in get_source
#     frame = inspect.getframeinfo(sys._getframe(stacklevel))
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/inspect.py", line 1697, in getframeinfo
#     lines, lnum = findsource(frame)
#                   ^^^^^^^^^^^^^^^^^
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/inspect.py", line 1075, in findsource
#     module = getmodule(object, file)
#              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/inspect.py", line 1001, in getmodule
#     os.path.realpath(f)] = module.__name__
#     ^^^^^^^^^^^^^^^^^^^
#   File "<frozen posixpath>", line 415, in realpath
#   File "<frozen posixpath>", line 450, in _joinrealpath
# KeyboardInterrupt
#     from torch.distributed.fsdp._shard_utils import (
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/torch/distributed/fsdp/_shard_utils.py", line 18, in <module>
#     from torch.distributed.tensor import DeviceMesh, DTensor, Replicate, Shard as DShard
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/torch/distributed/tensor/__init__.py", line 4, in <module>
#     import torch.distributed.tensor._ops  # force import all built-in dtensor ops
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/torch/distributed/tensor/_ops/__init__.py", line 2, in <module>
#     from ._conv_ops import *  # noqa: F403
#     ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/torch/distributed/tensor/_ops/_conv_ops.py", line 5, in <module>
#     from torch.distributed.tensor._dtensor_spec import DTensorSpec, TensorMeta
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/torch/distributed/tensor/_dtensor_spec.py", line 6, in <module>
#     from torch.distributed.tensor.placement_types import (
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/torch/distributed/tensor/placement_types.py", line 10, in <module>
#     from torch.distributed.tensor._collective_utils import (
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/torch/distributed/tensor/_collective_utils.py", line 30, in <module>
#     @torch.library.register_fake("_dtensor::shard_dim_alltoall")
#      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/torch/library.py", line 1069, in register
#     use_lib._register_fake(
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/torch/library.py", line 198, in _register_fake
#     source = torch._library.utils.get_source(_stacklevel + 1)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/torch/_library/utils.py", line 54, in get_source
#     frame = inspect.getframeinfo(sys._getframe(stacklevel))
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/inspect.py", line 1697, in getframeinfo
#     lines, lnum = findsource(frame)
#                   ^^^^^^^^^^^^^^^^^
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/inspect.py", line 1075, in findsource
#     module = getmodule(object, file)
#              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/inspect.py", line 1001, in getmodule
#     os.path.realpath(f)] = module.__name__
#     ^^^^^^^^^^^^^^^^^^^
#   File "<frozen posixpath>", line 415, in realpath
#   File "<frozen posixpath>", line 450, in _joinrealpath
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[42], line 19
#      14 print(f"Epoch {epoch}/{n_epochs}: ", end="")
#      16 train_loss, train_rmse = train_one_epoch(
#      17     train_loader, model, loss_fn, optimizer, scheduler, epoch, device
#      18 )
# ---> 19 val_loss, val_rmse = valid_model(test_loader, model, loss_fn, device)
#      21 print(
#      22     f"Train RMSE: {train_rmse:.6f}, "
#      23     f"Average Train Loss: {train_loss:.6f}, "
#      24     f"Val RMSE: {val_rmse:.6f}, "
#      25     f"Average Val Loss: {val_loss:.6f}"
#      26 )
#      28 if val_rmse < best_rmse - min_delta:
#
# File ~/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/torch/utils/_contextlib.py:120, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     117 @functools.wraps(func)
#     118 def decorate_context(*args, **kwargs):
#     119     with ctx_factory():
# --> 120         return func(*args, **kwargs)
#
# Cell In[41], line 27, in valid_model(dataloader, model, loss_fn, device, print_batch_stats)
#      19 n_samples = 0
#      21 iterator = tqdm(
#      22     enumerate(dataloader),
#      23     total=n_batches,
#      24     disable=not print_batch_stats
#      25 )
# ---> 27 for batch_idx, batch in iterator:
#      28     # Supports (X, y) or (X, y, ...)
#      29     X, y = batch[0], batch[1]
#      30     X, y = X.to(device).float(), y.to(device).float()
#
# File ~/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File ~/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/torch/utils/data/dataloader.py:734, in _BaseDataLoaderIter.__next__(self)
#     731 if self._sampler_iter is None:
#     732     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     733     self._reset()  # type: ignore[call-arg]
# --> 734 data = self._next_data()
#     735 self._num_yielded += 1
#     736 if (
#     737     self._dataset_kind == _DatasetKind.Iterable
#     738     and self._IterableDataset_len_called is not None
#     739     and self._num_yielded > self._IterableDataset_len_called
#     740 ):
#
# File ~/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/torch/utils/data/dataloader.py:1492, in _MultiProcessingDataLoaderIter._next_data(self)
#    1489     return self._process_data(data, worker_id)
#    1491 assert not self._shutdown and self._tasks_outstanding > 0
# -> 1492 idx, data = self._get_data()
#    1493 self._tasks_outstanding -= 1
#    1494 if self._dataset_kind == _DatasetKind.Iterable:
#    1495     # Check for _IterableDatasetStopIteration
#
# File ~/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/torch/utils/data/dataloader.py:1454, in _MultiProcessingDataLoaderIter._get_data(self)
#    1450     # In this case, `self._data_queue` is a `queue.Queue`,. But we don't
#    1451     # need to call `.task_done()` because we don't use `.join()`.
#    1452 else:
#    1453     while True:
# -> 1454         success, data = self._try_get_data()
#    1455         if success:
#    1456             return data
#
# File ~/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/torch/utils/data/dataloader.py:1285, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1272 def _try_get_data(self, timeout=_utils.MP_STATUS_CHECK_INTERVAL):
#    1273     # Tries to fetch data from `self._data_queue` once for a given timeout.
#    1274     # This can also be used as inner loop of fetching without timeout, with
#    (...)   1282     # Returns a 2-tuple:
#    1283     #   (bool: whether successfully get data, any: data if successful else None)
#    1284     try:
# -> 1285         data = self._data_queue.get(timeout=timeout)
#    1286         return (True, data)
#    1287     except Exception as e:
#    1288         # At timeout and error, we manually check whether any worker has
#    1289         # failed. Note that this is the only mechanism for Windows to detect
#    1290         # worker failures.
#
# File ~/miniforge3/envs/eegdash_v3/lib/python3.11/multiprocessing/queues.py:113, in Queue.get(self, block, timeout)
#     111 if block:
#     112     timeout = deadline - time.monotonic()
# --> 113     if not self._poll(timeout):
#     114         raise Empty
#     115 elif not self._poll():
#
# File ~/miniforge3/envs/eegdash_v3/lib/python3.11/multiprocessing/connection.py:256, in _ConnectionBase.poll(self, timeout)
#     254 self._check_closed()
#     255 self._check_readable()
# --> 256 return self._poll(timeout)
#
# File ~/miniforge3/envs/eegdash_v3/lib/python3.11/multiprocessing/connection.py:423, in Connection._poll(self, timeout)
#     422 def _poll(self, timeout):
# --> 423     r = wait([self], timeout)
#     424     return bool(r)
#
# File ~/miniforge3/envs/eegdash_v3/lib/python3.11/multiprocessing/connection.py:930, in wait(object_list, timeout)
#     927     deadline = time.monotonic() + timeout
#     929 while True:
# --> 930     ready = selector.select(timeout)
#     931     if ready:
#     932         return [key.fileobj for (key, events) in ready]
#
# File ~/miniforge3/envs/eegdash_v3/lib/python3.11/selectors.py:415, in _PollLikeSelector.select(self, timeout)
#     413 ready = []
#     414 try:
# --> 415     fd_event_list = self._selector.poll(timeout)
#     416 except InterruptedError:
#     417     return ready
#
# KeyboardInterrupt:
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/asyncio/base_events.py", line 604, in run_forever
#     self._run_once()
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/asyncio/base_events.py", line 1873, in _run_once
#     event_list = self._selector.select(timeout)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/selectors.py", line 561, in select
#     kev_list = self._selector.control(None, max_ev, timeout)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/baristim/miniforge3/envs/eegdash_v3/lib/python3.11/site-packages/torch/utils/data/_utils/signal_handling.py", line 73, in handler
#     _error_if_any_worker_fails()
# RuntimeError: DataLoader worker (pid 14481) is killed by signal: Interrupt: 2.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# saving the model

torch.save(model.state_dict(), "model.pth")
